# %% [markdown]
# # Installation pandas

# %%
from idlelib.squeezer import Squeezer

from jupyter_core.troubleshoot import subs
from tornado.escape import squeeze

pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.9 MB 15.7 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.9 MB 15.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 15.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 14.9 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...

# %% [markdown]
# # importing the pandas

# %%
import pandas as pd

# %% [markdown]
# ## pandas series

# %%
#Strings

import numpy as np
import pandas as pd

Counters = ['india','pakistan','usa','srilanka']

print(pd.Series(Counters))
# Out:
# 0       india
# 1    pakistan
# 2         usa
# 3    srilanka
# dtype: str

# %%
marks = [93,63,76,98]
subject = ['science','maths','Telugu','Social']

print(pd.Series(marks,index=subject,name='Mahesh_markList'))
# Out:
# science    93
# maths      63
# Telugu     76
# Social     98
# Name: Mahesh_markList, dtype: int64

# %% [markdown]
# Series from Dict

# %%
marks = {
    'maths':93,
    'science':63,
    'Telugu':76,
    'Social':98
}

marks_Series = pd.Series(marks,name='Mahesh_markList')
print(marks_Series)
# Out:
# maths      93
# science    63
# Telugu     76
# Social     98
# Name: Mahesh_markList, dtype: int64

# %% [markdown]
# # Series Attribute

# %%
#Size
marks_Series.size
# Out:
# 4

# %%
#dtype

marks_Series.dtypes
# Out:
# dtype('int64')

# %%
#Name

marks_Series.name
# Out:
# 'Mahesh_markList'

# %%
#is_unique

marks_Series.is_unique
# Out:
# True

# %%
#Index

marks_Series.index
# Out:
# Index(['maths', 'science', 'Telugu', 'Social'], dtype='str')

# %%
#Index

marks_Series.index
# Out:
# Index(['maths', 'science', 'Telugu', 'Social'], dtype='str')

# %% [markdown]
# # Series using to read CSV file
#
# # Read CSV

# %%
#With one Col

#pd.read_csv("C:\Users\rahul\Desktop\CampusX\subs.csv")

import pandas as pd

subs = pd.read_csv(r"C:\Users\rahul\Desktop\CampusX\subs.csv")


print(type(subs))
# Out:
# <class 'pandas.DataFrame'>

# %%
import pandas as pd

subs = pd.read_csv(r"C:\Users\rahul\Desktop\CampusX\subs.csv").squeeze("columns")
type(subs)
print(subs)
subs.head()
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
runs = pd.read_csv(r"C:\Users\rahul\Desktop\CampusX\kohli_ipl.csv").squeeze('columns')
runs
type(runs)
# Out:
# pandas.DataFrame

# %%
import pandas as pd

runs = pd.read_csv(r"C:\Users\rahul\Desktop\CampusX\kohli_ipl.csv", index_col="match_no").squeeze("columns")
type(runs)
runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movie = pd.read_csv(r"C:\Users\rahul\Desktop\CampusX\bollywood.csv",index_col ='movie').squeeze('columns')
movie.head()
movie.tail()
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: str

# %%
runs.head(3)
type(runs)
# Out:
# pandas.Series

# %%
runs.tail(5)
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
#SAMPLE : Randomly selecting movies

movie.sample(6)
# Out:
# movie
# Dev (2004 film)                          Amitabh Bachchan
# Mughal-e-Azam                           Prithviraj Kapoor
# Once Upon ay Time in Mumbai Dobaara!         Akshay Kumar
# Raavan                                  Abhishek Bachchan
# Cash (2007 film)                               Ajay Devgn
# Ek Paheli Leela                               Sunny Leone
# Name: lead, dtype: str

# %%
##Value_Counts --> Movies

movie.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
#Sort_Values
top_value = runs.sort_values(ascending=False).head().values[0]
print(top_value)
# Out:
# 113

# %%
runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
#inplace -->make premanent  changes in arrays

runs.sort_values(inplace=True)
runs
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %% [markdown]
# #Sort index --> inplace --> movie

# %%
movie.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# # Series Maths methods

# %%
#Count : return the total number values

runs.count()
# Out:
# match_no    215
# runs        215
# dtype: int64

# %%
#Sum  -- product

#subs.sum()

subs.prod()
# Out:
# np.int64(0)

# %%
#Mean --> Median --> mode --> std --> var
print(subs.mean())

print(subs.median())

print(movie.mode())

print(subs.std())

print(runs.var())
# Out:
# 135.64383561643837
# 123.0
# 0    Akshay Kumar
# Name: lead, dtype: str
# 62.6750230372527
# match_no    3870.000000
# runs         688.002478
# dtype: float64

# %%
#min/max

print(runs.min())
print(runs.max())
# Out:
# match_no    1
# runs        0
# dtype: int64
# match_no    215
# runs        113
# dtype: int64

# %%
#Describe

runs.describe()
# Out:
#          match_no        runs
# count  215.000000  215.000000
# mean   108.000000   30.855814
# std     62.209324   26.229801
# min      1.000000    0.000000
# 25%     54.500000    9.000000
# 50%    108.000000   24.000000
# 75%    161.500000   48.000000
# max    215.000000  113.000000

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
#integer indexing

x = pd.Series([12,13,14,15,16,17,18,19])
x[7]
# Out:
# np.int64(19)

# %% [markdown]
# # in Series work fine for +ve indexing but -ve indexing not work

# %%
#Slicing
runs[5:16]
# Out:
#     match_no  runs
# 5          6     9
# 6          7    34
# 7          8     0
# 8          9    21
# 9         10     3
# 10        11    10
# 11        12    38
# 12        13     3
# 13        14    11
# 14        15    50
# 15        16     2

# %%
runs[-5:]
# Out:
#      match_no  runs
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7

# %%
movie[-6:]
# Out:
# movie
# Kaante                    Amitabh Bachchan
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: str

# %%
#Alternate movies

movie[::2]
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: str

# %%
#Fancy indexing
runs.iloc[[1,3,5,7]]
# Out:
#    match_no  runs
# 1         2    23
# 3         4    12
# 5         6     9
# 7         8     0

# %%
#Indexing with labels --> fancy indexing
movie.iloc[[1,15,7]]
# Out:
# movie
# Battalion 609             Vicky Ahuja
# Badla (2019 film)    Amitabh Bachchan
# Bombairiya               Radhika Apte
# Name: lead, dtype: str

# %%
#Editing Series

#Using the indexing:
marks_Series
# Out:
# maths      93
# science    63
# Telugu     76
# Social     98
# Name: Mahesh_markList, dtype: int64

# %%
marks_Series.iloc[1] = 100
marks_Series
# Out:
# maths       93
# science    100
# Telugu      76
# Social      98
# Name: Mahesh_markList, dtype: int64

# %%
#What if an index does not exist

marks_Series['English'] = 90
marks_Series
# Out:
# maths       93
# science    100
# Telugu      76
# Social      98
# English     90
# Name: Mahesh_markList, dtype: int64

# %%
runs
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %% [markdown]
# Series with python Functionality

# %%
#Len/type/dir/sorted/max/min

print(len(subs))
print(type(subs))
print(dir(subs))
# Out:
# 365
# <class 'pandas.Series'>
# ...

# %%
print(sorted(subs)) ## Data stored in the list
# Out:
# [33, 33, 35, 37, 39, 40, 40, 40, 40, 42, 42, 43, 44, 44, 44, 45, 46, 46, 48, 49, 49, 49, 49, 50, 50, 50, 51, 54, 56, 56, 56, 56, 57, 61, 62, 64, 65, 65, 66, 66, 66, 66, 67, 68, 70, 70, 70, 71, 71, 72, 72, 72, 72, 72, 73, 74, 74, 75, 76, 76, 76, 76, 77, 77, 78, 78, 78, 79, 79, 80, 80, 80, 81, 81, 82, 82, 83, 83, 83, 84, 84, 84, 85, 86, 86, 86, 87, 87, 87, 87, 88, 88, 88, 88, 88, 89, 89, 89, 90, 90, 90, 90, 91, 92, 92, 92, 93, 93, 93, 93, 95, 95, 96, 96, 96, 96, 97, 97, 98, 98, 99, 99, 100, 100, 100, 101, 101, 101, 102, 102, 103, 103, 104, 104, 104, 105, 105, 105, 105, 105, 105, 105, 105, 105, 108, 108, 108, 108, 108, 108, 109, 109, 110, 110, 110, 111, 111, 112, 113, 113, 113, 114, 114, 114, 114, 115, 115, 115, 115, 117, 117, 117, 118, 118, 119, 119, 119, 119, 120, 122, 123, 123, 123, 123, 123, 124, 125, 126, 127, 128, 128, 129, 130, 131, 131, 132, 132, 134, 134, 134, 135, 135, 136, 136, 136, 137, 138, 138, 138, 139, 140, 144, 145, 146, 146, 146, 146, 147, 149, 150, 150, 150, 150, 151,
# ...

# %%
print(max(subs))
print(min(subs))
# Out:
# 396
# 33

# %%
#Type converstion

list(marks_Series)
# Out:
# [93, 63, 76, 98]

# %%
dict(marks_Series)
# Out:
# {'maths': np.int64(93),
#  'science': np.int64(63),
#  'Telugu': np.int64(76),
#  'Social': np.int64(98)}

# %%
#membership operation

movie


'Hum Tumhare Hain Sanam' in movie
# Out:
# True

# %%
movie

'Shah Rukh Khan' in movie ## o/p false ,bcsz its check the index not values

'Shah Rukh Khan' in movie.values
# Out:
# True

# %%
for i in movie.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
#Arithmetic operators (Broadcasting)

100 + marks_Series

100 - marks_Series
# Out:
# maths       7
# science    37
# Telugu     24
# Social      2
# Name: Mahesh_markList, dtype: int64

# %%
count_50_plus = (runs >= 50).sum()
print(count_50_plus)
# Out:
# match_no    166
# runs         50
# dtype: int64

# %%
runs[runs >= 50].count()
# Out:
# match_no    166
# runs         50
# dtype: int64

# %%
#find number of ducks

runs[runs == 0].count()
# Out:
# match_no    0
# runs        9
# dtype: int64

# %%
  movie.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %% [markdown]
# **Plotting Graphs on series**

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movie.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
movie.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: >

# %% [markdown]
# # Some important series methods
#
# 1. astype
# 2. between
# 3. clip
# 4. drop_duplicates
# 5. isnull
# 6. dropna
# 7. fillna
# 8. isin
# 9. apply
# 10. copy

# %%
import numpy as np
import  pandas as pd

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movie
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %%
#astype

import sys
sys.getsizeof(runs)
# Out:
# 3604

# %%
sys.getsizeof(runs.astype('int16'))
# Out:
# 1024

# %%
#Between

runs[runs.between(51,99)]
# Out:
# match_no
# 34     58
# 41     71
# 44     56
# 45     67
# 52     70
# 57     57
# 68     73
# 71     51
# 73     58
# 74     65
# 80     57
# 81     93
# 82     99
# 85     56
# 97     67
# 99     73
# 103    51
# 104    62
# 110    82
# 116    75
# 117    79
# 119    80
# 122    52
# 127    75
# 129    54
# 131    54
# 132    62
# 134    64
# 137    55
# 141    58
# 144    57
# 145    92
# 148    68
# 152    70
# 160    84
# 162    67
# 175    72
# 178    90
# 188    72
# 197    51
# 198    53
# 209    58
# 213    73
# Name: runs, dtype: int64

# %%
type(runs)
# Out:
# pandas.Series

# %%
vk_runs = pd.read_csv(r"C:\Users\rahul\Desktop\CampusX\kohli_ipl.csv").squeeze('columns')
vk_runs
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
#Clip

subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
#drop_duplicate

temp = pd.Series([1,2,1,3,4,5,6,4,3,1])

temp
# Out:
# 0    1
# 1    2
# 2    1
# 3    3
# 4    4
# 5    5
# 6    6
# 7    4
# 8    3
# 9    1
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
temp.drop_duplicates()
# Out:
# 0    1
# 1    2
# 3    3
# 4    4
# 5    5
# 6    6
# dtype: int64

# %%
#nan

temp = pd.Series([1,2,1,np.nan,3,4,5,6,np.nan,4,3,1])

temp
# Out:
# 0     1.0
# 1     2.0
# 2     1.0
# 3     NaN
# 4     3.0
# 5     4.0
# 6     5.0
# 7     6.0
# 8     NaN
# 9     4.0
# 10    3.0
# 11    1.0
# dtype: float64

# %%
temp.dropna(

)
# Out:
# 0     1.0
# 1     2.0
# 2     1.0
# 4     3.0
# 5     4.0
# 6     5.0
# 7     6.0
# 9     4.0
# 10    3.0
# 11    1.0
# dtype: float64

# %%
#Fillna

temp.fillna(temp.mean())
# Out:
# 0    1
# 1    2
# 2    1
# 3    3
# 4    4
# 5    5
# 6    6
# 7    4
# 8    3
# 9    1
# dtype: int64

# %%
#isin

runs[runs.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
#Apply

movie.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: str

# %%
#apply

subs.apply(lambda  x:'good day' if x > subs.mean() else 'Bad Day')
# Out:
# 0       Bad Day
# 1       Bad Day
# 2       Bad Day
# 3       Bad Day
# 4       Bad Day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: str

# %%
#Copy
new_Vk=runs.head(10)

# %%
new_Vk
# Out:
# match_no
# 1      1
# 2     23
# 3     13
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# Name: runs, dtype: int64

# %%
new_Vk[2] = 50
new_Vk

runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = runs.head().copy()

new[1] = 100
new
new_Vk
runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
