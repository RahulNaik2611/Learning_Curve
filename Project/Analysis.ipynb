# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import  matplotlib.pyplot as plt

# %%
#Define the stock to analyze
stocks = ['AAPL','GOOGL','AMZN']

#Define the time period (Last 2 years )

start_date = '2024-01-01'
end_date = '2025-01-01'


#Dowmload data for the each stock
stock_date = yf.download(stocks, start_date, end_date)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
#Fetch the top 5

stock_date.head()
# Out:
# Price            Close                                High              \
# Ticker            AAPL        AMZN       GOOGL        AAPL        AMZN
# Date
# 2024-01-02  183.562180  149.929993  136.955582  186.330843  152.380005
# 2024-01-03  182.187744  148.470001  137.698990  183.799505  151.050003
# 2024-01-04  179.873947  144.570007  135.191223  181.040733  147.380005
# 2024-01-05  179.152130  145.240005  134.537033  180.714448  146.589996
# 2024-01-08  183.483093  149.100006  137.619690  183.522654  149.399994
#
# Price                          Low                                Open  \
# Ticker           GOOGL        AAPL        AMZN       GOOGL        AAPL
# Date
# 2024-01-02  138.224330  181.831767  148.389999  135.280433  185.055273
# 2024-01-03  138.402756  181.376915  148.330002  135.875166  182.158081
# 2024-01-04  137.936881  178.855477  144.050003  135.151581  180.111251
# 2024-01-05  135.954472  178.153440  144.529999  133.962129  179.953077
# ...

# %%
#Finally save the data to CSV file for the future analysis

stock_date.to_csv('stock_date.csv')

# %% [markdown]
# # Data Manipulation

# %%
df =pd.read_csv(r'C:\Users\rahul\PycharmProjects\learning_curve\Project\stock_date.csv')

df.head()
# Out:
#         Price              Close             Close.1             Close.2  \
# 0      Ticker               AAPL                AMZN               GOOGL
# 1        Date                NaN                 NaN                 NaN
# 2  2024-01-02  183.5621795654297  149.92999267578125  136.95558166503906
# 3  2024-01-03   182.187744140625  148.47000122070312  137.69898986816406
# 4  2024-01-04  179.8739471435547  144.57000732421875  135.19122314453125
#
#                  High             High.1              High.2  \
# 0                AAPL               AMZN               GOOGL
# 1                 NaN                NaN                 NaN
# 2  186.33084291740326  152.3800048828125   138.2243301608941
# 3  183.79950485996184  151.0500030517578   138.4027561263541
# 4  181.04073256447913  147.3800048828125  137.93688094484938
#
#                   Low               Low.1               Low.2  \
# 0                AAPL                AMZN               GOOGL
# ...

# %%
#Data cleaning  --> outlier,Null,Nan
#print(df.isnull())  #Return the Boolean values

str_cols = df.select_dtypes(include=['object', 'string']).columns
df[str_cols] = df[str_cols].fillna("0")


print(df.head())
# Out:
#         Price              Close             Close.1             Close.2  \
# 0      Ticker               AAPL                AMZN               GOOGL
# 1        Date                  0                   0                   0
# 2  2024-01-02  183.5621795654297  149.92999267578125  136.95558166503906
# 3  2024-01-03   182.187744140625  148.47000122070312  137.69898986816406
# 4  2024-01-04  179.8739471435547  144.57000732421875  135.19122314453125
#
#                  High             High.1              High.2  \
# 0                AAPL               AMZN               GOOGL
# 1                   0                  0                   0
# 2  186.33084291740326  152.3800048828125   138.2243301608941
# 3  183.79950485996184  151.0500030517578   138.4027561263541
# 4  181.04073256447913  147.3800048828125  137.93688094484938
#
#                   Low               Low.1               Low.2  \
# 0                AAPL                AMZN               GOOGL
# ...

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3

# %%
#Drop Nan

print(df.dropna(inplace=True))

df
# Out:
# None
#           Price               Close             Close.1             Close.2  \
# 0        Ticker                AAPL                AMZN               GOOGL
# 2    2024-01-02   183.5621795654297  149.92999267578125  136.95558166503906
# 3    2024-01-03    182.187744140625  148.47000122070312  137.69898986816406
# 4    2024-01-04   179.8739471435547  144.57000732421875  135.19122314453125
# 5    2024-01-05  179.15213012695312  145.24000549316406   134.5370330810547
# ..          ...                 ...                 ...                 ...
# 249  2024-12-24    256.560791015625   229.0500030517578  195.09100341796875
# 250  2024-12-26   257.3755798339844   227.0500030517578   194.5836639404297
# 251  2024-12-27  253.96737670898438              223.75  191.75839233398438
# 252  2024-12-30  250.59890747070312   221.3000030517578  190.24630737304688
# 253  2024-12-31  248.83021545410156  219.38999938964844  188.31639099121094
#
# ...

# %% [markdown]
# # #Statistical analysis

# %%
print(df.columns)


print('--------------------------------------')
df1 = df[['Price','High']]

print("Fetch top 5 rows ")

df1.head()
# Out:
# Index(['Price', 'Close', 'Close.1', 'Close.2', 'High', 'High.1', 'High.2',
#        'Low', 'Low.1', 'Low.2', 'Open', 'Open.1', 'Open.2', 'Volume',
#        'Volume.1', 'Volume.2'],
#       dtype='str')
# --------------------------------------
# Fetch top 5 rows
#         Price                High
# 0      Ticker                AAPL
# 1        Date                 NaN
# 2  2024-01-02  186.33084291740326
# 3  2024-01-03  183.79950485996184
# 4  2024-01-04  181.04073256447913

# %%
#Running sum


# Convert 'High' to numeric, forcing errors to NaN
df1['High'] = pd.to_numeric(df1['High'], errors='coerce')

# Now apply cumulative sum
df1['AAPL_HIGH_Cumsum'] = df1['High'].cumsum()

print(df1.head())
# Out:
#         Price        High  AAPL_HIGH_Cumsum
# 0      Ticker         NaN               NaN
# 1        Date         NaN               NaN
# 2  2024-01-02  186.330843        186.330843
# 3  2024-01-03  183.799505        370.130348
# 4  2024-01-04  181.040733        551.171080
